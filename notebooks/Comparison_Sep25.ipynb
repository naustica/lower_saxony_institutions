# %%
from google.cloud import bigquery
from matplotlib.ticker import StrMethodFormatter
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import seaborn as sns

# %%
sns.set_style('whitegrid')
plt.rc('font', family='Arial')
plt.rc('font', size=9) 
plt.rc('axes', titlesize=9) 
plt.rc('axes', labelsize=9) 
plt.rc('xtick', labelsize=9) 
plt.rc('ytick', labelsize=9) 
plt.rc('legend', fontsize=9)

# %%
client = bigquery.Client(project='subugoe-collaborative')

# %%
check_ror_null = client.query(f"""
                                SELECT dfg_inst_id, ror_id, inst_name
                                FROM `subugoe-collaborative.openbib.kb_inst_lookup` AS kba, UNNEST(current_sectors) AS sector
                                JOIN `subugoe-collaborative.resources.inst_with_federal_state` AS fs
                                  ON fs.dfg_inst_id = kba.dfg_instituts_id
                                WHERE federal_state = 'Niedersachsen' 
                                  AND ror_id IS NULL 
                                  AND sector IN ('fh', 'uni')
                              """).to_dataframe()

# %%
check_ror_null
# Out:
# Empty DataFrame
# Columns: [dfg_inst_id, ror_id, inst_name]
# Index: []

# %% [markdown]
# #### Wichtig: Universitätsmedizin Göttingen wird in GERIT und in der Bielefelder Institutionskodierung zur Universität Göttingen gezählt!
#
# ROR UMG: https://ror.org/021ft0n22
#
# ROR GAU: https://ror.org/01y9bpm73

# %%
oal_inst_lower_saxony_raw = client.query(f"""
                            SELECT DISTINCT 
                                kb.id AS kb_id, 
                                oal.id AS oal_id, 
                                kb.source AS kb_source, 
                                oal.source AS oal_source,
                                kb.inst_name AS kb_name,
                                oal.inst_name AS oal_name,
                                ARRAY_TO_STRING(kb.current_sectors, ',') AS kb_sectors,
                                ARRAY_TO_STRING(oal.current_sectors, ',') AS oal_sectors
                            FROM (
                                SELECT o.id, current_sectors, federal_states.inst_name, 'KB' AS source
                                FROM `subugoe-collaborative.openbib.kb_a_addr_inst` AS inst
                                JOIN `subugoe-collaborative.openbib.kb_inst_lookup` AS kb_inst
                                  ON inst.inst_id_top = kb_inst.inst_id
                                JOIN `subugoe-collaborative.resources.inst_with_federal_state` AS federal_states
                                  ON CASE
                                        WHEN kb_inst.inst_id = 621 THEN 'https://ror.org/03m2kj587'
                                        ELSE kb_inst.ror 
                                     END = CONCAT('https://ror.org/', federal_states.ror_id)
                                JOIN `subugoe-collaborative.openalex.works` AS o
                                    ON inst.openalex_id = o.id
                                WHERE publication_year BETWEEN 2020 AND 2024 
                                  AND type='article' 
                                  AND federal_states.federal_state = 'Niedersachsen'
                            ) AS kb
                            FULL OUTER JOIN (
                              SELECT o.id, current_sectors, federal_states.inst_name, 'OAL' AS source
                                FROM (
                                  SELECT oal.id, 
                                         CASE 
                                          WHEN inst.ror = 'https://ror.org/021ft0n22' THEN 'https://ror.org/01y9bpm73'
                                          ELSE inst.ror
                                         END AS ror
                                  FROM `subugoe-collaborative.openalex.works` AS oal, UNNEST(authorships) AS aut, UNNEST(aut.institutions) AS inst
                                  WHERE publication_year BETWEEN 2020 AND 2024 
                                  AND oal.type='article' 
                                ) AS o
                                JOIN `subugoe-collaborative.resources.inst_with_federal_state` AS federal_states
                                    ON o.ror = CONCAT('https://ror.org/', federal_states.ror_id)
                                LEFT JOIN `subugoe-collaborative.openbib.kb_inst_lookup` AS kb_inst
                                    ON kb_inst.ror = CONCAT('https://ror.org/', federal_states.ror_id)
                                WHERE federal_states.federal_state = 'Niedersachsen'
                            ) AS oal
                              ON kb.id = oal.id
                            """).to_dataframe()

# %%
oal_inst_lower_saxony = oal_inst_lower_saxony_raw[
    (oal_inst_lower_saxony_raw['kb_sectors'].str.contains('uni')) 
    | (oal_inst_lower_saxony_raw['kb_sectors'].str.contains('fh(?!g)', regex=True))
    | (oal_inst_lower_saxony_raw['oal_sectors'].str.contains('uni'))
    | (oal_inst_lower_saxony_raw['oal_sectors'].str.contains('fh(?!g)', regex=True))
]

# %%
oal_inst_lower_saxony
# Out:
#                                    kb_id                            oal_id  \
# 6       https://openalex.org/W4309740956  https://openalex.org/W4309740956
# 9       https://openalex.org/W4402783630  https://openalex.org/W4402783630
# 11      https://openalex.org/W3028245168  https://openalex.org/W3028245168
# 13      https://openalex.org/W3132913110  https://openalex.org/W3132913110
# 14      https://openalex.org/W4220724224  https://openalex.org/W4220724224
# ...                                  ...                               ...
# 116236  https://openalex.org/W3210146342  https://openalex.org/W3210146342
# 116237  https://openalex.org/W3015068359  https://openalex.org/W3015068359
# 116238  https://openalex.org/W3034175744  https://openalex.org/W3034175744
# 116239  https://openalex.org/W3207363777  https://openalex.org/W3207363777
# 116240  https://openalex.org/W3017127897  https://openalex.org/W3017127897
#
#        kb_source oal_source  \
# 6             KB        OAL
# 9             KB        OAL
# 11            KB        OAL
# 13            KB        OAL
# 14            KB        OAL
# ...          ...        ...
# 116236        KB        OAL
# 116237        KB        OAL
# 116238        KB        OAL
# 116239        KB        OAL
# 116240        KB        OAL
#
#                                                   kb_name  \
# 6         Deutsches Institut für Lebensmitteltechnik e.V.
# 9                        PFH Private Hochschule Göttingen
# 11      Max-Planck-Institut zur Erforschung multirelig...
# 13            Nordwestdeutsche Forstliche Versuchsanstalt
# 14      Fraunhofer-Institut für Holzforschung - Wilhel...
# ...                                                   ...
# 116236                              Universität Osnabrück
# 116237                              Universität Osnabrück
# 116238                              Universität Osnabrück
# 116239                              Universität Osnabrück
# 116240                              Universität Osnabrück
#
#                                    oal_name kb_sectors oal_sectors
# 6                      Hochschule Osnabrück         ev          fh
# 9          PFH Private Hochschule Göttingen         fh          fh
# 11       Georg-August-Universität Göttingen        mpg         uni
# 13       Georg-August-Universität Göttingen      res-l         uni
# 14      Technische Universität Braunschweig        fhg         uni
# ...                                     ...        ...         ...
# 116236                Universität Osnabrück        uni         uni
# 116237                Universität Osnabrück        uni         uni
# 116238                Universität Osnabrück        uni         uni
# 116239                Universität Osnabrück        uni         uni
# 116240                Universität Osnabrück        uni         uni
#
# [92568 rows x 8 columns]

# %%
oal_inst_lower_saxony.kb_source.count()
# Out:
# 88818

# %%
oal_inst_lower_saxony.oal_source.count()
# Out:
# 90797

# %%
kb_list = oal_inst_lower_saxony.groupby('kb_id')['kb_name'].apply(set).reset_index()

# %%
oal_list = oal_inst_lower_saxony.groupby('oal_id')['oal_name'].apply(set).reset_index()

# %%
inst_list = pd.merge(kb_list, oal_list, left_on='kb_id', right_on='oal_id', how='outer')

# %%
inst_list['kb_name'] = inst_list['kb_name'].fillna('').apply(set)
inst_list['oal_name'] = inst_list['oal_name'].fillna('').apply(set)

inst_list['in_oal_missing'] = list(inst_list['kb_name'] - inst_list['oal_name'])
inst_list['in_kb_missing'] = list(inst_list['oal_name'] - inst_list['kb_name'])

inst_list['kb_count'] = inst_list.kb_name.str.len()
inst_list['oal_count'] = inst_list.oal_name.str.len()

# %%
inst_list[inst_list.in_oal_missing.str.len() > 0]
# Out:
#                                   kb_id  \
# 6       https://openalex.org/W173619620
# 22     https://openalex.org/W2340624100
# 24     https://openalex.org/W2396187297
# 31     https://openalex.org/W2550770972
# 49     https://openalex.org/W2757461179
# ...                                 ...
# 66200  https://openalex.org/W4407893398
# 66209  https://openalex.org/W4408145603
# 66239  https://openalex.org/W4408795219
# 66264  https://openalex.org/W4410358849
# 66266  https://openalex.org/W4410537553
#
#                                                  kb_name  \
# 6                        {Leuphana Universität Lüneburg}
# 22      {Gottfried Wilhelm Leibniz Universität Hannover}
# 24      {Gottfried Wilhelm Leibniz Universität Hannover}
# 31                  {Georg-August-Universität Göttingen}
# 49                  {Georg-August-Universität Göttingen}
# ...                                                  ...
# 66200  {Georg-August-Universität Göttingen, Gesellsch...
# 66209                            {Universität Osnabrück}
# 66239      {Physikalisch-Technische Bundesanstalt (PTB)}
# 66264                            {Universität Osnabrück}
# 66266   {Gottfried Wilhelm Leibniz Universität Hannover}
#
#                                  oal_id  \
# 6                                   NaN
# 22     https://openalex.org/W2340624100
# 24                                  NaN
# 31     https://openalex.org/W2550770972
# 49                                  NaN
# ...                                 ...
# 66200  https://openalex.org/W4407893398
# 66209                               NaN
# 66239  https://openalex.org/W4408795219
# 66264                               NaN
# 66266                               NaN
#
#                                                 oal_name  \
# 6                                                     {}
# 22     {Helmholtz-Zentrum für Infektionsforschung (HZI)}
# 24                                                    {}
# 31     {Technische Informationsbibliothek (TIB), Gese...
# 49                                                    {}
# ...                                                  ...
# 66200               {Georg-August-Universität Göttingen}
# 66209                                                 {}
# 66239              {Technische Universität Braunschweig}
# 66264                                                 {}
# 66266                                                 {}
#
#                                           in_oal_missing  \
# 6                        {Leuphana Universität Lüneburg}
# 22      {Gottfried Wilhelm Leibniz Universität Hannover}
# 24      {Gottfried Wilhelm Leibniz Universität Hannover}
# 31                  {Georg-August-Universität Göttingen}
# 49                  {Georg-August-Universität Göttingen}
# ...                                                  ...
# 66200  {Gesellschaft für wissenschaftliche Datenverar...
# 66209                            {Universität Osnabrück}
# 66239      {Physikalisch-Technische Bundesanstalt (PTB)}
# 66264                            {Universität Osnabrück}
# 66266   {Gottfried Wilhelm Leibniz Universität Hannover}
#
#                                            in_kb_missing  kb_count  oal_count
# 6                                                     {}         1          0
# 22     {Helmholtz-Zentrum für Infektionsforschung (HZI)}         1          1
# 24                                                    {}         1          0
# 31     {Gesellschaft für wissenschaftliche Datenverar...         1          2
# 49                                                    {}         1          0
# ...                                                  ...       ...        ...
# 66200                                                 {}         2          1
# 66209                                                 {}         1          0
# 66239              {Technische Universität Braunschweig}         1          1
# 66264                                                 {}         1          0
# 66266                                                 {}         1          0
#
# [3334 rows x 8 columns]

# %%
inst_list[inst_list.in_kb_missing.str.len() > 0]
# Out:
#                                   kb_id  \
# 12      https://openalex.org/W192689753
# 22     https://openalex.org/W2340624100
# 25     https://openalex.org/W2462619985
# 31     https://openalex.org/W2550770972
# 43     https://openalex.org/W2732479381
# ...                                 ...
# 69987                               NaN
# 69988                               NaN
# 69989                               NaN
# 69990                               NaN
# 69991                               NaN
#
#                                                 kb_name  \
# 12     {Gottfried Wilhelm Leibniz Universität Hannover}
# 22     {Gottfried Wilhelm Leibniz Universität Hannover}
# 25             {Medizinische Hochschule Hannover (MHH)}
# 31                 {Georg-August-Universität Göttingen}
# 43                 {Georg-August-Universität Göttingen}
# ...                                                 ...
# 69987                                                {}
# 69988                                                {}
# 69989                                                {}
# 69990                                                {}
# 69991                                                {}
#
#                                  oal_id  \
# 12      https://openalex.org/W192689753
# 22     https://openalex.org/W2340624100
# 25     https://openalex.org/W2462619985
# 31     https://openalex.org/W2550770972
# 43     https://openalex.org/W2732479381
# ...                                 ...
# 69987  https://openalex.org/W4413640333
# 69988  https://openalex.org/W4414084594
# 69989  https://openalex.org/W4414360822
# 69990  https://openalex.org/W4414360888
# 69991  https://openalex.org/W4414373276
#
#                                                 oal_name  \
# 12     {Gottfried Wilhelm Leibniz Universität Hannove...
# 22     {Helmholtz-Zentrum für Infektionsforschung (HZI)}
# 25     {Georg-August-Universität Göttingen, Medizinis...
# 31     {Technische Informationsbibliothek (TIB), Gese...
# 43     {Georg-August-Universität Göttingen, Institut ...
# ...                                                  ...
# 69987                            {Universität Osnabrück}
# 69988  {Medizinische Hochschule Hannover (MHH), Gottf...
# 69989               {Georg-August-Universität Göttingen}
# 69990   {Gottfried Wilhelm Leibniz Universität Hannover}
# 69991                               {Universität Vechta}
#
#                                          in_oal_missing  \
# 12                                                   {}
# 22     {Gottfried Wilhelm Leibniz Universität Hannover}
# 25                                                   {}
# 31                 {Georg-August-Universität Göttingen}
# 43                                                   {}
# ...                                                 ...
# 69987                                                {}
# 69988                                                {}
# 69989                                                {}
# 69990                                                {}
# 69991                                                {}
#
#                                            in_kb_missing  kb_count  oal_count
# 12                              {Leibniz-Fachhochschule}         1          2
# 22     {Helmholtz-Zentrum für Infektionsforschung (HZI)}         1          1
# 25                  {Georg-August-Universität Göttingen}         1          2
# 31     {Gesellschaft für wissenschaftliche Datenverar...         1          2
# 43     {Institut für Nanophotonik Göttingen e.V. (IFN...         1          2
# ...                                                  ...       ...        ...
# 69987                            {Universität Osnabrück}         0          1
# 69988  {Medizinische Hochschule Hannover (MHH), Gottf...         0          2
# 69989               {Georg-August-Universität Göttingen}         0          1
# 69990   {Gottfried Wilhelm Leibniz Universität Hannover}         0          1
# 69991                               {Universität Vechta}         0          1
#
# [5009 rows x 8 columns]

# %%
inst_list.kb_count.sum()
# Out:
# 75475

# %%
inst_list.oal_count.sum()
# Out:
# 76819

# %%
inst_list.kb_count.mean()
# Out:
# 1.07833752428849

# %%
inst_list.oal_count.mean()
# Out:
# 1.0975397188250087

# %%
kb_c = inst_list.explode('kb_name').groupby(['kb_name'])['kb_id'].count().reset_index().rename(columns={'kb_id': 'n_kb'})

# %%
oal_c = inst_list.explode('oal_name').groupby(['oal_name'])['oal_id'].count().reset_index().rename(columns={'oal_id': 'n_oal'})

# %%
table_c = pd.merge(kb_c, oal_c, left_on='kb_name', right_on='oal_name', how='outer')

# %%
table_c['n_kb'] = table_c['n_kb'].fillna(0)
table_c['n_oal'] = table_c['n_oal'].fillna(0)

table_c['n_kb'] = table_c['n_kb'].astype(int)
table_c['n_oal'] = table_c['n_oal'].astype(int)

# %%
filter_uni_fh = client.query(f"""
                                SELECT dfg_inst_id, ror_id, inst_name
                                FROM `subugoe-collaborative.openbib.kb_inst_lookup` AS kba, UNNEST(current_sectors) AS sector
                                JOIN `subugoe-collaborative.resources.inst_with_federal_state` AS fs
                                  ON fs.dfg_inst_id = kba.dfg_instituts_id
                                WHERE federal_state = 'Niedersachsen' 
                                  AND sector IN ('fh', 'uni')
                              """).to_dataframe()

# %%
inst_tab = pd.merge(table_c, filter_uni_fh, how='right', left_on='oal_name', right_on='inst_name')
inst_tab['difference'] = inst_tab['n_kb'] - inst_tab['n_oal']

# %%
inst_tab[['inst_name', 'ror_id', 'n_kb', 'n_oal', 'difference']]
# Out:
#                                             inst_name     ror_id   n_kb  \
# 0            Carl von Ossietzky Universität Oldenburg  033n9gh91   5720
# 1    Jade Hochschule Wilhelmshaven/Oldenburg/Elsfleth  02vvvm705    324
# 2                               Universität Osnabrück  04qmmjx98   2999
# 3   Ostfalia Hochschule für angewandte Wissenschaften  01bk10867    396
# 4      Gottfried Wilhelm Leibniz Universität Hannover  0304hq317  11418
# 5                                 Hochschule Hannover  03m2kj587     78
# 6              Medizinische Hochschule Hannover (MHH)  00f2yqf98  13128
# 7                  Georg-August-Universität Göttingen  01y9bpm73  19053
# 8   Fachhochschule für die Wirtschaft Hannover (FHDW)  03z6vda50     20
# 9                 Technische Universität Braunschweig  010nsgg66   7953
# 10                              Hochschule Emden/Leer  01bc76c69    281
# 11                    Stiftung Universität Hildesheim  02f9det96    928
# 12         Stiftung Tierärztliche Hochschule Hannover  015qjqf64   2190
# 13                   Technische Universität Clausthal  04qb8nc58   2017
# 14                               Hochschule Osnabrück  059vymd37    571
# 15                                 Universität Vechta  045y6d111    347
# 16                      Leuphana Universität Lüneburg  02w2y2t16   2078
# 17                   PFH Private Hochschule Göttingen  01we8bn75     71
# 18                            Hochschule 21 Buxtehude  00xdvw685      6
# 19                           Hochschule Weserbergland  0367m1n91     17
#
#     n_oal  difference
# 0    5859        -139
# 1     331          -7
# 2    3098         -99
# 3     407         -11
# 4   10972         446
# 5     139         -61
# 6   13205         -77
# 7   19612        -559
# 8      27          -7
# 9    8071        -118
# 10    326         -45
# 11   1113        -185
# 12   2619        -429
# 13   2041         -24
# 14    466         105
# 15    410         -63
# 16   2376        -298
# 17     93         -22
# 18      7          -1
# 19     20          -3

# %%
inst_tab[['inst_name', 'ror_id', 'n_kb', 'n_oal', 'difference']].to_csv('../data/inst_tab_sep25.csv', sep=',', index=False)

# %%
fig, ax = plt.subplots(figsize=(4.5, 3.5))

plt.grid(True)

t = 1.25

x = [x for x in range(0, int(inst_tab.n_oal.max() * t), 1000)]
y = x

sns.scatterplot(data=inst_tab, 
                x='n_kb', 
                y='n_oal',
                color='#56B4E9',
                alpha=0.8)

sns.lineplot(x=x, 
             y=y, 
             color='#c3c3c3', 
             linestyle='dashed', 
             linewidth=1.1,
             alpha=1)

ax.xaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}'))
ax.yaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}'))

ax.set(xlabel='Anzahl der Artikel in OPENBIB', ylabel='Anzahl der Artikel in OpenAlex')

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9,5.5))
plt.box(False)

change_color = ['#c3c3c3' if (x < 0) else '#56B4E9' for x in inst_tab.difference]

sns.barplot(data=inst_tab, 
            x='difference', 
            y='inst_name', 
            orient='h',
            saturation=1,
            palette=change_color,
            hue='inst_name',
            alpha=0.9,
            zorder=3,
            errorbar=None)

for idx, row in inst_tab.iterrows():
    plt.text(row['difference'] - 55, idx+0.05, row['difference'], verticalalignment='center')

ax.xaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

ax.set(xlabel='Anzahl der Publikationen (Unterschied zu OpenAlex)', ylabel='Einrichtung')

plt.tight_layout()

plt.show()

# %%
table_c[table_c.kb_name.isnull()]
# Out:
#    kb_name  n_kb                                           oal_name  n_oal
# 56     NaN     0                 Forschungsinstitut für Philosophie     27
# 57     NaN     0                          Hanse-Wissenschaftskolleg     20
# 58     NaN     0           Institut für Palliative Care (ipac) e.V.      3
# 59     NaN     0  Niedersächsische Akademie der Wissenschaften z...     20
# 60     NaN     0  Niedersächsisches Institut für frühkindliche B...      1
# 61     NaN     0  ifh Göttingen - Volkswirtschaftliches Institut...     21
